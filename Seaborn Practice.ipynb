# %%
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("kc_house_data.csv")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
# LINE GRAPHS

# %%
ax = sns.lineplot(x = 'yr_built', y = 'price', data = df)

# %%
print(df.shape)
# Out:
# (21613, 21)

# %%
ax = sns.lineplot(x = 'yr_built', y = 'price', data = df, hue = 'grade')

# %%
sns.set(rc={'figure.figsize':(15,8)})
ax = sns.lineplot(x = 'yr_built', y = 'price', data = df)

# %%
sns.set(rc={'figure.figsize':(15,8)})
ax = sns.lineplot(x = 'yr_built', y = 'price', data = df, ci=False)

# %%
ax = sns.lineplot(x = 'yr_built', y = 'price', data = df, ci=False, markers = True)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
## HISTOGRAMS

# %%
ax = sns.barplot(x = 'floors', y = 'price', data = df)
## this plot takes the mean by default

# %%
ax = sns.barplot(x = 'floors', y = 'price', data = df, ci = False)

# %%
ax = sns.barplot(x = 'floors', y = 'price', data = df, ci = False, hue = 'waterfront')

# %%
ax = sns.barplot(x = 'price', y = 'floors', data = df, ci = False, hue = 'waterfront', orient = 'h')

# %%
ax = sns.barplot(x = 'price', y = 'floors', data = df, ci = False, hue = 'waterfront', orient = 'h', color = 'green')

# %%
ax = sns.barplot(x = 'price', y = 'floors', data = df, ci = False, hue = 'waterfront', orient = 'h', color = 'orange')

# %%
ax = sns.barplot(x = 'price', y = 'floors', data = df, ci = False, hue = 'waterfront', orient = 'h', color = 'pink')

# %%
# DISTRIBUTIONS

# %%
df.price
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df.price.values
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %%
x = df.price.values

# %%
sns.distplot(x)

# %%
sns.distplot(x, color = 'blue')

# %%
mean = df['price'].mean()
mean
# Out:
# 540088.1417665294

# %%
sns.distplot(x, color = 'blue')
plt.axvline(mean,0,1, color = 'red')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
y = df.sqft_living

sns.distplot(y, color = 'red')

mean1 = df.sqft_living.mean()

plt.axvline(mean1, 0, 1, color = 'black')

# %%
# BOX PLOTS

# %%
z = df.price.values
z
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %%
sns.set(rc={'figure.figsize':(25,8)})
sns.boxplot(z)

# %%
df.price.median()
# Out:
# 450000.0

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
ax = sns.boxplot(x = 'bedrooms', y = 'price', data = df)

# %%
ax_bathrooms = sns.boxplot(x = 'bathrooms', y = 'price', data = df)

# %%
ax = sns.boxplot(x = 'bedrooms', y = 'price', data = df, color = 'blue')

# %%
ax = sns.boxplot(x = 'bedrooms', y = 'price', data = df, hue = 'waterfront')

# %%
# SCATTER PLOTS

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
ax = sns.scatterplot(x = 'sqft_living', y ='price', data = df)

# %%
ax = sns.scatterplot(x = 'sqft_living', y ='price', data = df, hue = 'waterfront')

# %%
ax = sns.scatterplot(x = 'sqft_living', y ='price', data = df, hue = 'waterfront', size = 'view')

# %%
ax = sns.scatterplot(x = 'sqft_living', y ='price', data = df, hue = 'waterfront', size = 'view', sizes = (20,200))

# %%
ax = sns.scatterplot(x = 'sqft_living', y ='price', data = df, hue = 'waterfront', style = 'view')

# %%
# LMPLOTS

# %%
ax = sns.lmplot(x ='sqft_living', y = 'price', data = df, height = 10, aspect = 2)

# %%
ax = sns.lmplot(x ='sqft_living', y = 'price', data = df, height = 10, aspect = 2, hue = 'waterfront')

# %%
ax = sns.lmplot(x ='sqft_living', y = 'price', data = df, height = 10, aspect = 2, hue = 'waterfront', ci = None, markers = ['o', 'x'])

# %%
ax = sns.lmplot(x ='sqft_living', y = 'price', data = df, height = 5, aspect = 2, col = 'waterfront', ci = None)

# %%
ax = sns.lmplot(x ='sqft_living', y = 'price', data = df, height = 5, aspect = 2, col = 'waterfront', ci = None, 
                line_kws = {'color': 'red'},
                scatter_kws = {'color' : 'black'})

# %%
# SUB PLOTS

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
fig, axis = plt.subplots(2,2, figsize = (12,7))

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
fig, axis = plt.subplots(2,2, figsize = (12,7))


# plot 1 

ax1 = sns.lineplot(x = 'yr_built', y = 'price', data = df, ci=False, ax = axis[0,0])

# plot 2

ax2 = sns.barplot(x = 'floors', y = 'price', data = df, ci = False, ax = axis[0,1])

# plot 3

ax3 = sns.scatterplot(x = 'sqft_living', y ='price', data = df, ax = axis[1,0])

# plot 4

ax4 = sns.boxplot(x = 'bedrooms', y = 'price', data = df, ax = axis[1,1])

# %%
df2 = df[df['bedrooms'] < 6]  
df2.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
ax5 = sns.boxplot(x = 'bedrooms', y = 'price', data = df2)

# %%
fig, axis = plt.subplots(2,2, figsize = (12,7))


# plot 1 

ax1 = sns.lineplot(x = 'yr_built', y = 'price', data = df, ci=False, ax = axis[0,0])

# plot 2

ax2 = sns.barplot(x = 'floors', y = 'price', data = df, ci = False, ax = axis[0,1])

# plot 3

ax3 = sns.scatterplot(x = 'sqft_living', y ='price', data = df, ax = axis[1,0])

# plot 4

ax4 = sns.boxplot(x = 'bedrooms', y = 'price', data = df2, ax = axis[1,1])

# %%
# PAIRPLOT  -  this plots every veriable with every variable - just a quick overview, if there isn't too much data

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
g = sns.pairplot(df[['price', 'sqft_living', 'sqft_above']], height = 5, kind = 'reg')

# %%
ax = sns.jointplot('bedrooms', 'price', data = df)

# %%
ax = sns.jointplot('bedrooms', 'price', data = df, color = 'green', height = 10)

# %%
ax = sns.jointplot('bedrooms', 'price', data = df, color = 'green', height = 10, kind = 'reg')

# %%
# HEATMAP

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
pc = df[['price','bedrooms', 'sqft_above','view','waterfront']].corr()
pc
# Out:
#                price  bedrooms  sqft_above      view  waterfront
# price       1.000000  0.308350    0.605567  0.397293    0.266369
# bedrooms    0.308350  1.000000    0.477616  0.079532   -0.006582
# sqft_above  0.605567  0.477616    1.000000  0.167648    0.072074
# view        0.397293  0.079532    0.167648  1.000000    0.401857
# waterfront  0.266369 -0.006582    0.072074  0.401857    1.000000

# %%
hm = sns.heatmap(pc)

# %%
hm = sns.heatmap(pc, annot = True)

# %%
hm = sns.heatmap(pc, annot = True, annot_kws = {'size' : 30})

# %%
hm = sns.heatmap(pc, annot = True, annot_kws = {'size' : 30}, cmap = 'YlGnBu')
